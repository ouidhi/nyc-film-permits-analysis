# %% [markdown]
# # **NYC Film Permits Analysis**
# ## Data Cleaning and pre-processing for analysis

# %%
# importing libraries
import numpy as np
import pandas as pd

# %%
# Importing data file
df = pd.read_csv('data.csv')
df.head()
# Out:
#    EventID                      EventType           StartDateTime  \
# 0   753784  Theater Load in and Load Outs  12/24/2023 12:01:00 AM
# 1   752706                Shooting Permit  12/13/2023 06:00:00 AM
# 2   753230                Shooting Permit  12/18/2023 07:00:00 AM
# 3   752951                Shooting Permit  12/14/2023 07:00:00 AM
# 4   752181                Shooting Permit  12/13/2023 06:00:00 AM
#
#               EndDateTime               EnteredOn  \
# 0  12/31/2023 11:59:00 PM  12/18/2023 12:59:21 PM
# 1  12/13/2023 08:00:00 PM  12/06/2023 09:01:38 AM
# 2  12/18/2023 11:59:00 PM  12/12/2023 10:09:19 AM
# 3  12/14/2023 09:00:00 PM  12/08/2023 09:29:50 AM
# 4  12/13/2023 11:59:00 PM  12/01/2023 09:38:19 AM
#
#                                EventAgency  \
# 0  Mayor's Office of Media & Entertainment
# 1  Mayor's Office of Media & Entertainment
# 2  Mayor's Office of Media & Entertainment
# 3  Mayor's Office of Media & Entertainment
# 4  Mayor's Office of Media & Entertainment
#
#                                          ParkingHeld    Borough  \
# 0  WEST   62 STREET between COLUMBUS AVENUE and A...  Manhattan
# 1  HUDSON STREET between MORTON STREET and BARROW...  Manhattan
# 2  ROSE FEISS BOULEVARD between EAST  139 STREET ...      Bronx
# 3  ATLANTIC AVENUE between WASHINGTON AVENUE and ...   Brooklyn
# 4  GRAND AVENUE between 64 STREET and FLUSHING AV...     Queens
#
#   CommunityBoard(s) PolicePrecinct(s)    Category  SubCategoryName  \
# 0                 7                20     Theater          Theater
# 1           1, 2, 3   5, 6, 7, 84, 90        Film          Feature
# 2                 1                40  Television  Episodic series
# 3                 8                77  Television  Episodic series
# 4              1, 5           104, 94  Television  Episodic series
#
#                     Country                         ZipCode(s)
# 0  United States of America                              10023
# 1  United States of America  10002, 10014, 10038, 11201, 11211
# 2  United States of America                              10454
# 3  United States of America                              11238
# 4  United States of America                       11222, 11378

# %%
print('Dimensions of the table: ',df.shape)
print(df.info())
# Out:
# Dimensions of the table:  (12441, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12441 entries, 0 to 12440
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EventID            12441 non-null  int64
#  1   EventType          12441 non-null  object
#  2   StartDateTime      12441 non-null  object
#  3   EndDateTime        12441 non-null  object
#  4   EnteredOn          12441 non-null  object
#  5   EventAgency        12441 non-null  object
#  6   ParkingHeld        12441 non-null  object
#  7   Borough            12441 non-null  object
#  8   CommunityBoard(s)  12438 non-null  object
#  9   PolicePrecinct(s)  12438 non-null  object
#  10  Category           12441 non-null  object
#  11  SubCategoryName    12441 non-null  object
#  12  Country            12441 non-null  object
#  13  ZipCode(s)         12438 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 1.3+ MB
# None

# %%
# Finding the unique fields
print(df.nunique())
# Out:
# EventID              12441
# EventType                4
# StartDateTime         5407
# EndDateTime           6624
# EnteredOn            12437
# EventAgency              1
# ParkingHeld           6543
# Borough                  5
# CommunityBoard(s)      311
# PolicePrecinct(s)      718
# Category                 9
# SubCategoryName         26
# Country                  4
# ZipCode(s)            1334
# dtype: int64

# %%
# keeping the original data as df and copying to new to apply changes
data = df

# %%
# counting the ParkingHeld values and making a new column for that
data['ParkingHeldCount'] = data['ParkingHeld'].apply(
    lambda x: len([y for y in x.split(',') if y.strip()]))

# %%
data.head()
# Out:
#    EventID                      EventType           StartDateTime  \
# 0   753784  Theater Load in and Load Outs  12/24/2023 12:01:00 AM
# 1   752706                Shooting Permit  12/13/2023 06:00:00 AM
# 2   753230                Shooting Permit  12/18/2023 07:00:00 AM
# 3   752951                Shooting Permit  12/14/2023 07:00:00 AM
# 4   752181                Shooting Permit  12/13/2023 06:00:00 AM
#
#               EndDateTime               EnteredOn  \
# 0  12/31/2023 11:59:00 PM  12/18/2023 12:59:21 PM
# 1  12/13/2023 08:00:00 PM  12/06/2023 09:01:38 AM
# 2  12/18/2023 11:59:00 PM  12/12/2023 10:09:19 AM
# 3  12/14/2023 09:00:00 PM  12/08/2023 09:29:50 AM
# 4  12/13/2023 11:59:00 PM  12/01/2023 09:38:19 AM
#
#                                EventAgency  \
# 0  Mayor's Office of Media & Entertainment
# 1  Mayor's Office of Media & Entertainment
# 2  Mayor's Office of Media & Entertainment
# 3  Mayor's Office of Media & Entertainment
# 4  Mayor's Office of Media & Entertainment
#
#                                          ParkingHeld    Borough  \
# 0  WEST   62 STREET between COLUMBUS AVENUE and A...  Manhattan
# 1  HUDSON STREET between MORTON STREET and BARROW...  Manhattan
# 2  ROSE FEISS BOULEVARD between EAST  139 STREET ...      Bronx
# 3  ATLANTIC AVENUE between WASHINGTON AVENUE and ...   Brooklyn
# 4  GRAND AVENUE between 64 STREET and FLUSHING AV...     Queens
#
#   CommunityBoard(s) PolicePrecinct(s)    Category  SubCategoryName  \
# 0                 7                20     Theater          Theater
# 1           1, 2, 3   5, 6, 7, 84, 90        Film          Feature
# 2                 1                40  Television  Episodic series
# 3                 8                77  Television  Episodic series
# 4              1, 5           104, 94  Television  Episodic series
#
#                     Country                         ZipCode(s)  \
# 0  United States of America                              10023
# 1  United States of America  10002, 10014, 10038, 11201, 11211
# 2  United States of America                              10454
# 3  United States of America                              11238
# 4  United States of America                       11222, 11378
#
#    ParkingHeldCount
# 0                 3
# 1                13
# 2                 5
# 3                 7
# 4                 8

# %%
# since multiple zipcodes are there in each row

data['ZipCode'] = data['ZipCode(s)'].str.split(',')
data = data.explode('ZipCode')
data['ZipCode'] = data['ZipCode'].str.strip()

# %%
# dropping columns irrelevant to my analysis

data.drop(columns=['CommunityBoard(s)',
                   'PolicePrecinct(s)', 
                   'ZipCode(s)', 
                   'EventAgency',
                   'ParkingHeld'], inplace= True)

# EventAgency has only one value, it doesn't have any effect on the analysis, hence, dropping it.

# %%
# Updating the datatypes

data = data.astype({'EventType': 'category',
                'StartDateTime': 'datetime64[ns]',
                'EndDateTime': 'datetime64[ns]',
                'EnteredOn': 'datetime64[ns]',
                'Borough': 'category',
                'Category': 'category',
                'SubCategoryName': 'category',
                'Country': 'category',
                'ParkingHeldCount': 'int'})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19216 entries, 0 to 12440
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EventID           19216 non-null  int64
#  1   EventType         19216 non-null  category
#  2   StartDateTime     19216 non-null  datetime64[ns]
#  3   EndDateTime       19216 non-null  datetime64[ns]
#  4   EnteredOn         19216 non-null  datetime64[ns]
#  5   Borough           19216 non-null  category
#  6   Category          19216 non-null  category
#  7   SubCategoryName   19216 non-null  category
#  8   Country           19216 non-null  category
#  9   ParkingHeldCount  19216 non-null  int64
#  10  ZipCode           19213 non-null  object
# dtypes: category(5), datetime64[ns](3), int64(2), object(1)
# memory usage: 1.1+ MB

# %%
print(data.describe(include= 'number'))
print('\nFor date columns:\n')
print(data[['StartDateTime', 'EndDateTime', 'EnteredOn']].agg(['count', 'min', 'max']))
# Out:
#              EventID  ParkingHeldCount
# count   19216.000000      19216.000000
# mean   769089.210346          4.082639
# std     46294.145894          3.748236
# min    677665.000000          1.000000
# 25%    728716.750000          1.000000
# 50%    773169.500000          3.000000
# 75%    810678.750000          6.000000
# max    849655.000000         24.000000
#
# For date columns:
#
#              StartDateTime          EndDateTime            EnteredOn
# count                19216                19216                19216
# min    2023-01-01 00:01:00  2023-01-01 11:00:00  2022-10-20 11:11:11
# max    2025-04-15 08:00:00  2025-04-24 23:59:00  2025-04-11 14:49:26

# %%
data.isnull().sum()
# Out:
# EventID             0
# EventType           0
# StartDateTime       0
# EndDateTime         0
# EnteredOn           0
# Borough             0
# Category            0
# SubCategoryName     0
# Country             0
# ParkingHeldCount    0
# ZipCode             3
# dtype: int64

# %%
data.fillna({'ZipCode': 'Unknown'}, inplace= True)
data.astype({'ZipCode': 'str'})
# Out:
#        EventID                      EventType       StartDateTime  \
# 0       753784  Theater Load in and Load Outs 2023-12-24 00:01:00
# 1       752706                Shooting Permit 2023-12-13 06:00:00
# 1       752706                Shooting Permit 2023-12-13 06:00:00
# 1       752706                Shooting Permit 2023-12-13 06:00:00
# 1       752706                Shooting Permit 2023-12-13 06:00:00
# ...        ...                            ...                 ...
# 12437   847216  Theater Load in and Load Outs 2025-04-14 00:01:00
# 12438   848251                Shooting Permit 2025-04-14 09:00:00
# 12439   844295                Shooting Permit 2025-04-15 06:00:00
# 12440   693463                Shooting Permit 2023-02-02 06:00:00
# 12440   693463                Shooting Permit 2023-02-02 06:00:00
#
#               EndDateTime           EnteredOn    Borough    Category  \
# 0     2023-12-31 23:59:00 2023-12-18 12:59:21  Manhattan     Theater
# 1     2023-12-13 20:00:00 2023-12-06 09:01:38  Manhattan        Film
# 1     2023-12-13 20:00:00 2023-12-06 09:01:38  Manhattan        Film
# 1     2023-12-13 20:00:00 2023-12-06 09:01:38  Manhattan        Film
# 1     2023-12-13 20:00:00 2023-12-06 09:01:38  Manhattan        Film
# ...                   ...                 ...        ...         ...
# 12437 2025-04-17 06:00:00 2025-04-02 13:34:35  Manhattan     Theater
# 12438 2025-04-15 01:00:00 2025-04-07 10:57:28     Queens  Television
# 12439 2025-04-15 23:59:00 2025-03-21 13:55:06  Manhattan         WEB
# 12440 2023-02-02 20:00:00 2023-01-30 08:19:27   Brooklyn  Television
# 12440 2023-02-02 20:00:00 2023-01-30 08:19:27   Brooklyn  Television
#
#        SubCategoryName                   Country  ParkingHeldCount ZipCode
# 0              Theater  United States of America                 3   10023
# 1              Feature  United States of America                13   10002
# 1              Feature  United States of America                13   10014
# 1              Feature  United States of America                13   10038
# 1              Feature  United States of America                13   11201
# ...                ...                       ...               ...     ...
# 12437          Theater  United States of America                 2   10001
# 12438  Episodic series  United States of America                 4   11101
# 12439   Not Applicable  United States of America                 1   10003
# 12440  Episodic series  United States of America                 2   11237
# 12440  Episodic series  United States of America                 2   11385
#
# [19216 rows x 11 columns]

# %%
data.isna().sum()
# Out:
# EventID             0
# EventType           0
# StartDateTime       0
# EndDateTime         0
# EnteredOn           0
# Borough             0
# Category            0
# SubCategoryName     0
# Country             0
# ParkingHeldCount    0
# ZipCode             0
# dtype: int64

# %%
data.head()
# Out:
#    EventID                      EventType       StartDateTime  \
# 0   753784  Theater Load in and Load Outs 2023-12-24 00:01:00
# 1   752706                Shooting Permit 2023-12-13 06:00:00
# 1   752706                Shooting Permit 2023-12-13 06:00:00
# 1   752706                Shooting Permit 2023-12-13 06:00:00
# 1   752706                Shooting Permit 2023-12-13 06:00:00
#
#           EndDateTime           EnteredOn    Borough Category SubCategoryName  \
# 0 2023-12-31 23:59:00 2023-12-18 12:59:21  Manhattan  Theater         Theater
# 1 2023-12-13 20:00:00 2023-12-06 09:01:38  Manhattan     Film         Feature
# 1 2023-12-13 20:00:00 2023-12-06 09:01:38  Manhattan     Film         Feature
# 1 2023-12-13 20:00:00 2023-12-06 09:01:38  Manhattan     Film         Feature
# 1 2023-12-13 20:00:00 2023-12-06 09:01:38  Manhattan     Film         Feature
#
#                     Country  ParkingHeldCount ZipCode
# 0  United States of America                 3   10023
# 1  United States of America                13   10002
# 1  United States of America                13   10014
# 1  United States of America                13   10038
# 1  United States of America                13   11201

# %%
data[data['ZipCode'] == 'Unknown']
# Out:
#        EventID        EventType       StartDateTime         EndDateTime  \
# 4175    704436  Shooting Permit 2023-03-30 05:00:00 2023-03-30 10:00:00
# 4959    697195  Shooting Permit 2023-02-26 01:00:00 2023-02-26 13:00:00
# 12187   845230  Shooting Permit 2025-04-02 09:00:00 2025-04-03 18:00:00
#
#                 EnteredOn    Borough           Category  SubCategoryName  \
# 4175  2023-03-27 15:03:44   Brooklyn         Television  Episodic series
# 4959  2023-02-21 07:43:20  Manhattan         Television             News
# 12187 2025-03-25 16:32:24   Brooklyn  Still Photography   Not Applicable
#
#                         Country  ParkingHeldCount  ZipCode
# 4175   United States of America                 1  Unknown
# 4959   United States of America                 1  Unknown
# 12187  United States of America                 1  Unknown

# %%
# finally exporting as a csv file
data.to_excel('cleaned_data.xlsx', index= False)
